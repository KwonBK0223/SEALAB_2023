# %%
import pandas as pd
import netCDF4 as nc

# %%
# NetCDF 파일 열기
file_path = "data/wind_velocity2016.nc"
dataset = nc.Dataset(file_path, "r")

# %%
# 파일 내의 변수 이름 확인
variables = dataset.variables.keys()
print(variables)
# Out:
# dict_keys(['longitude', 'latitude', 'time', 'u10', 'v10'])

# %%
time = pd.DataFrame(dataset["time"][:])
for i in range(len(time)):
    time.iloc[i] = 0.25 * i
time
# Out:
#            0
# 0       0.00
# 1       0.25
# 2       0.50
# 3       0.75
# 4       1.00
# ...      ...
# 2919  729.75
# 2920  730.00
# 2921  730.25
# 2922  730.50
# 2923  730.75
#
# [2924 rows x 1 columns]

# %% [markdown]
# 2016년 윤년이라 2월달에 29일까지 있음...

# %%
lon = pd.DataFrame(dataset["longitude"][:])
lon
# Out:
#              0
# 0   123.870003
# 1   124.120003
# 2   124.370003
# 3   124.620003
# 4   124.870003
# ..         ...
# 87  145.619995
# 88  145.869995
# 89  146.119995
# 90  146.369995
# 91  146.619995
#
# [92 rows x 1 columns]

# %%
lat = pd.DataFrame(dataset["latitude"][:])
lat
# Out:
#             0
# 0   53.419998
# 1   53.169998
# 2   52.919998
# 3   52.669998
# 4   52.419998
# ..        ...
# 89  31.170000
# 90  30.920000
# 91  30.670000
# 92  30.420000
# 93  30.170000
#
# [94 rows x 1 columns]

# %%
u10_0 = pd.DataFrame(dataset["u10"][0][:])
u10_0
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.971710  0.744317  0.549026  0.401890  0.019335 -0.375705 -0.730616
# 1   1.357832  1.199103  0.982411  0.781770  0.359086 -0.066272 -0.452394
# 2   1.447005  1.310570  1.160758  1.003812  0.751451  0.351952 -0.043087
# 3   1.431846  1.335538  1.178593  0.986869  0.750559  0.483038  0.112967
# 4   1.407769  1.308786  1.231205  1.059992  0.868268  0.606097  0.390297
# ..       ...       ...       ...       ...       ...       ...       ...
# 89 -1.851530 -1.704393 -1.568849 -1.439547 -1.230881 -1.081961 -0.897371
# 90 -2.213575 -2.072681 -1.955863 -1.838154 -1.720444 -1.592926 -1.472542
# 91 -2.600589 -2.498039 -2.383005 -2.258162 -2.145803 -2.075356 -1.970131
# 92 -2.976010 -2.883269 -2.812822 -2.687979 -2.614857 -2.551543 -2.506065
# 93 -3.248882 -3.248882 -3.208753 -3.183785 -3.116013 -3.084802 -3.043782
#
#           7         8         9   ...         82         83         84  \
# 0  -0.904505 -1.056100 -1.086419  ...  10.706803  11.028720  11.380956
# 1  -0.817115 -0.999921 -1.213046  ...  10.227940  10.446415  10.816486
# 2  -0.455070 -0.763611 -1.036482  ...   9.756211   9.964877  10.268068
# 3  -0.201816 -0.494306 -0.848326  ...   9.321043   9.487798   9.780288
# 4   0.102266 -0.183982 -0.536218  ...   9.166773   9.320152   9.463721
# ..       ...       ...       ...  ...        ...        ...        ...
# 89 -0.722591 -0.590614 -0.535326  ...  12.491168  12.517921  12.553590
# 90 -1.307570 -1.181835 -1.114955  ...  12.286069  12.270909  12.159442
# 91 -1.925544 -1.822994 -1.757006  ...  11.793830  11.735867  11.631534
# 92 -2.494472 -2.483771 -2.415999  ...  11.209742  11.161589  11.195475
# 93 -3.058050 -3.055375 -3.083910  ...  10.584635  10.712153  10.779033
#
#            85         86         87         88         89         90  \
# 0   11.270380  11.019802   8.989317   7.468014   5.119179   2.919263
# 1   11.150888  11.340828  11.455862  10.362592   9.277348   7.004311
# 89 -6.740201 -6.621348 -6.576299 -6.617514 -6.668314 -6.540835
# 90 -6.896436 -6.783333 -6.744035 -6.786209 -6.687484 -6.505371
# 91 -6.857137 -6.767998 -6.728699 -6.720073 -6.578216 -6.486201
# 92 -6.683650 -6.598344 -6.686526 -6.704737 -6.786209 -6.732533
# 93 -6.503454 -6.650103 -6.793877 -7.023915 -7.165772 -7.238617
#
# [94 rows x 92 columns]

# %%
t = [i for i in range(int(0 * 100), int((730.75 + 0.25) * 100), int(0.25 * 100)) for _ in range(8648)]
t = [x / 100 for x in t]

lati = []
for i in range(len(lat)):
    cnt = [lat.iloc[i][0]] * 92
    lati += cnt
lati *= 2924

long = []
for i in range(len(lon)):
    long.append(lon.iloc[i][0])
long *= 94
long *= 2924

u_lst = []
for i in range(2924):
    x = pd.DataFrame(dataset["u10"][i][:])
    new_x = x.values.flatten().tolist()
    u_lst.append(new_x)

v_lst = []
for i in range(2924):
    x = pd.DataFrame(dataset["v10"][i][:])
    new_x = x.values.flatten().tolist()
    v_lst.append(new_x)

def flatten(lst):
    flattened_lst = []
    for sublist in lst:
        for item in sublist:
            flattened_lst.append(item)
    return flattened_lst

u_lst = flatten(u_lst)
v_lst = flatten(v_lst)

# %%
print(len(t))
print(len(lati))
print(len(long))
print(len(u_lst))
print(len(v_lst))
# Out:
# 25286752
# 25286752
# 25286752
# 25286752
# 25286752

# %%
data = {
    "time" : t,
    "longitude" : long,
    "latitude" : lati,
    "u" : u_lst,
    "v" : v_lst
}
columns = ["time","longitude","latitude","u","v"]
total = pd.DataFrame(data, columns = columns)
total
# Out:
#             time   longitude   latitude         u         v
# 0           0.00  123.870003  53.419998  0.971710 -0.804258
# 1           0.00  124.120003  53.419998  0.744317 -0.908734
# 2           0.00  124.370003  53.419998  0.549026 -1.036213
# 3           0.00  124.620003  53.419998  0.401890 -0.998832
# 4           0.00  124.870003  53.419998  0.019335 -1.072636
# ...          ...         ...        ...       ...       ...
# 25286747  730.75  145.619995  30.170000  1.097445  8.145185
# 25286748  730.75  145.869995  30.170000  0.249403  7.878725
# 25286749  730.75  146.119995  30.170000 -0.138503  7.554754
# 25286750  730.75  146.369995  30.170000  0.027360  7.066882
# 25286751  730.75  146.619995  30.170000  0.952091  6.492745
#
# [25286752 rows x 5 columns]

# %%
total.describe()
# Out:
#                time     longitude      latitude             u             v
# count  2.528675e+07  2.528675e+07  2.528675e+07  2.528675e+07  2.528675e+07
# mean   3.653750e+02  1.352472e+02  4.179498e+01  1.171443e+00 -4.714212e-01
# std    2.110215e+02  2.198249e+01  6.677918e+00  4.145533e+00  4.322577e+00
# min    0.000000e+00  1.238700e+02  3.017000e+01 -2.664539e+01 -3.351569e+01
# 25%    1.826875e+02  1.295575e+02  3.592000e+01 -1.182727e+00 -2.716450e+00
# 50%    3.653750e+02  1.352450e+02  4.179500e+01  1.039482e+00 -2.742116e-01
# 75%    5.480625e+02  1.409325e+02  4.767000e+01  3.346405e+00  1.946615e+00
# max    7.307500e+02  1.466200e+02  5.342000e+01  3.179282e+01  2.929720e+01

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25286752 entries, 0 to 25286751
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   time       float64
#  1   longitude  float32
#  2   latitude   float32
#  3   u          float64
#  4   v          float64
# dtypes: float32(2), float64(3)
# memory usage: 771.7 MB

# %%
total.to_csv("data/wind_velocity2016.csv", index = False)
